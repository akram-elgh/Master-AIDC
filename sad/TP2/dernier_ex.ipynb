X10<-c(1.4, 1.7, 1.4, 1.6, 1.3, 1.4, 2.0, 1.6, 2.0, 2.0, 1.7, 2.0, 1.6, 1.4, 1.8, 1.9, 1.3, 1.9, 2.0, 1.9, 1.8, 1.8, 1.9, 2.0, 1.4, 2.0, 1.3, 1.8, 2.0, 2.0, 1.9, 2.0, 2.0)
Y<-c(2.37, 1.47, 1.13, 0.85, 0.24, 1.49, 0.30, 0.07, 3.00, 1.21, 0.38, 0.70, 2.64, 2.05, 1.75, 0.06, 0.13, 1.00, 0.41, 0.72, 0.67, 0.12, 0.97, 0.07, 0.10, 0.68, 0.13, 0.20, 1.09, 0.18, 0.35, 0.21, 0.03)
log_Y<-c(0.86289, 0.38526, 0.12222, -0.16252, -1.42712, 0.39878, -1.20397, -2.65926, 1.09861, 0.19062, -0.96758, -0.35667, 0.97078, 0.71784, 0.55962, -2.81341, -2.04022, 0.00000, -0.89160, -0.32850, -0.40048, -2.12026, -0.03046, -2.65926, -2.30259, -0.38566, -2.04022, -1.60944, 0.08618, -1.71480, -1.04982, -1.56065, -3.50656)

# %% [markdown]
# On veut savoir quelle sont les variables qui influence Y

# %%
vars <- data.frame(X1, X2, X3, X4, X5, X6, X7, X8, X9, X10)

# %%
mat <- data.frame(X1, X2, X3, X4, X5, X6, X7, X8, X9, X10, Y)

# %%
library(car)
library(corrplot)
library(stats)
library(factoextra)
# Out:
# Loading required package: ggplot2
#
# Welcome! Want to learn more? See two factoextra-related books at https://goo.gl/ve3WBa

# %%
# on normalise les donnees
mat <- scale(mat)
mat
# Out:
#       X1           X2           X3          X4          X5          X6
#  [1,] -0.893800639 -0.962578437 -1.09627645 -0.43382827 -0.10494125 -1.1025308
#  [2,]  0.206659107 -0.141067529 -0.36224787 -0.04949719  0.63880345 -0.4055286
#  [3,] -0.653559427 -0.141067529 -0.67683154 -1.97115262 -1.73188279 -0.6843294
#  [4,] -0.475315947 -0.141067529  0.68636438 -1.39465599 -1.40649448  0.7096750
#  [5,]  0.322904855  0.406606409 -0.46710909 -0.72207659 -1.05786415 -0.5449290
#  [6,] -0.506314813 -0.277986014 -1.09627645 -0.04949719 -0.10494125 -1.1025308
#  [7,]  0.826636429  1.091198831  1.10580928 -1.39465599 -1.66215672  1.2672767
#  [8,] -0.049081538  2.323465192 -0.46710909  1.19957885  1.01067580 -0.4055286
#  [9,] -1.459529946 -0.688741468 -0.99141522 -0.91424213 -0.61626573 -1.1025308
# [10,] -1.862515205  0.680443378 -0.25738664 -0.14557996 -0.75571786 -0.2661281
# [11,] -1.157291001 -0.688741468  0.58150316  1.00741330  0.33665717  0.8490754
# ...

# %%
cor_mat <- cor(mat)
cor_mat
# Out:
#     X1          X2         X3         X4          X5          X6
# X1   1.00000000  0.1205209  0.5408659  0.32105284  0.28377386  0.5146683
# X2   0.12052094  1.0000000  0.2927776  0.13668772  0.11341631  0.3006666
# X3   0.54086588  0.2927776  1.0000000  0.39806248  0.29690060  0.9261061
# X4   0.32105284  0.1366877  0.3980625  1.00000000  0.90465522  0.4392997
# X5   0.28377386  0.1134163  0.2969006  0.90465522  1.00000000  0.3062303
# X6   0.51466830  0.3006666  0.9261061  0.43929974  0.30623032  1.0000000
# X7   0.26849282 -0.1522218  0.1512322  0.05810293 -0.07870719  0.1506780
# X8   0.36014656  0.2619061  0.7227343  0.77192534  0.59619783  0.8102161
# X9   0.36372429  0.3256728  0.7639890  0.45958851  0.26746450  0.9085319
# X10 -0.09993082  0.1293432  0.2061772 -0.04540116 -0.02458364  0.1300913
# Y   -0.53021877 -0.4554582 -0.5158178 -0.35790141 -0.15777120 -0.5702405
#     X7          X8          X9          X10         Y
# ...

# %%
corrplot(cor_mat)
# Out:
# Plot with title “”

# %%
data.pca <- princomp(cor_mat)
summary(data.pca)
# Out:
# Importance of components:
#                          Comp.1    Comp.2     Comp.3     Comp.4    Comp.5
# Standard deviation     1.061797 0.4803955 0.37009750 0.27338458 0.2504241
# Proportion of Variance 0.676262 0.1384298 0.08216068 0.04483114 0.0376170
# Cumulative Proportion  0.676262 0.8146918 0.89685248 0.94168362 0.9793006
#                            Comp.6      Comp.7       Comp.8       Comp.9
# Standard deviation     0.16675557 0.076906328 0.0243457601 1.231641e-02
# Proportion of Variance 0.01667986 0.003547774 0.0003555318 9.099127e-05
# Cumulative Proportion  0.99598049 0.999528260 0.9998837916 9.999748e-01
#                             Comp.10 Comp.11
# Standard deviation     6.483832e-03       0
# Proportion of Variance 2.521711e-05       0
# Cumulative Proportion  1.000000e+00       1

# %%
data.pca$loadings[, 1:3]
# Out:
#     Comp.1      Comp.2      Comp.3
# X1   0.27194269  0.07616262  0.4400761154
# X2   0.18330383  0.15969955 -0.5370142806
# X3   0.36584025  0.18396707  0.0113433951
# X4   0.28248333 -0.50458347  0.0692907358
# X5   0.19777024 -0.58683086  0.0060519024
# X6   0.40198096  0.15983827  0.0008317094
# X7   0.01536906  0.29394928  0.6439568470
# X8   0.40296305 -0.16771376 -0.0513818267
# X9   0.40760678  0.13881825 -0.1262126231
# X10 -0.01430473  0.35202968 -0.2807250956
# Y   -0.38619407 -0.22934413 -0.0304098767

# %%
# data.pca

# %%
fviz_eig(data.pca, addlabels = TRUE)
# Out:
# plot without title

# %%
fviz_pca_var(data.pca, col.var = "contrib", gradient.cols = c("#00AFBB", "#E7B800", "#FC4E07"), repel = TRUE)
# Out:
# plot without title
