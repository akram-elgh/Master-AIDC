# %% [markdown]
# <h1 align="center"> TP1 Ex2 </h1>

# %%
chemin <- "europe.csv"
europe <- read.csv(chemin, dec = ".", sep = ";", quote = "\"", header = TRUE)
head(europe)
# Out:
#   Pays      Duree.heures.
# 1 Allemagne 41.7
# 2 Autriche  44.1
# 3 Belgique  41.0
# 4 Chypre    41.8
# 5 Danemark  40.5
# 6 Espagne   42.2

# %%
str(europe)
# Out:
# 'data.frame':	25 obs. of  2 variables:
#  $ Pays         : chr  "Allemagne" "Autriche" "Belgique" "Chypre" ...
#  $ Duree.heures.: num  41.7 44.1 41 41.8 40.5 42.2 41.5 40.5 41 44.1 ...

# %%
summary(europe)
# Out:
#      Pays           Duree.heures.
#  Length:25          Min.   :39.8
#  Class :character   1st Qu.:41.0
#  Mode  :character   Median :41.5
#                     Mean   :41.7
#                     3rd Qu.:42.5
#                     Max.   :44.1

# %%
names(europe) <- c("Pays", "Duree")
attach(europe)

# %%
range(Duree)
# Out:
# [1] 39.8 44.1

# %%
sd(Duree)
# Out:
# [1] 1.113358

# %%
plot(Duree)
# Out:
# plot without title

# %%
boxplot(Duree, ylab = "Duree (heures)")
# Out:
# plot without title

# %%
plot(Duree)
points(1, mean(Duree), pch = 3)
# Out:
# plot without title

# %%
hist(Duree)
# Out:
# Plot with title “Histogram of Duree”
